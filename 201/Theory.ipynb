# %% [markdown]
# # 201
#
# ### Input & Print
#
# #### Python data types
#     print(type(x))
#     - str
#     - int, float, complex
#     - dict (mapping)
#     - list, tuples, range (sequence)
#     - set, frozenset
#     - bool
#     - bytes, bytearray, memoryview (binary)
#     - NoneType
#
# print(10/5) #2.0 decimal
# print(10//5) # 2 no decimal
#
# ### Procedent
#
#     ()	Parentheses
#     **	Exponent
#     +x, -x, ~x	Unary plus, Unary minus, Bitwise NOT
#     *, /, //, %	Multiplication, Division, Floor division, Modulus
#     +, -	Addition, Subtraction
#     <<, >>	Bitwise shift operators
#     &	Bitwise AND
#     ^	Bitwise XOR
#     |	Bitwise OR
#     ==, !=, >, >=, <, <=, is, is not, in, not in	Comparisons, Identity, Membership operators
#     not	Logical NOT
#     and	Logical AND
#     or
#
#
#   # BITS
#
# | System| Base | Symbols |
# | --- | --- | --- |
# | Decimal | 10 | 0...9 |
# | Binary | 2 | 0,1 |
# | Hexadecimal | 16 | 0...9, A..F|
#
# ## Decimal 123
#
# | Power| 10^2 | 10^1 |  10^0 |
# | --- | --- | --- |--- |
# | Symbol | 1 | 2 | 3 |
# | Place | 100 | 10 |  1 |
# | Math | 1* 100 | 2 * 10 | 3 * 1 |
#
# ## Binary  101
#
# | Power| 2^2 | 2^1 |  2^0 |
# | --- | --- | --- |--- |
# | Symbol | 1 | 0 | 1 |
# | Place | 4 | 2 |  1 |
# | Math | 1* 4 | 0 * 2 | 1 * 1 |
#
#
# ## Extract numbers
#
# 5678 --- > Pa' sacarle el 6 (5678 % 1000) // 100
#      ----> FORMULA ES: (n % 10 ** i)//10**(i-1)
#        Donde n es el numero (5678), i es la posicion (6 osea 3 )
#
# 123  ----> para sacar el ultimo %100
#            para el penultimo %100 // 10 y asi sucesivamente
#
# #### Convertir decimal a entero
# print(123.45 * 10**2)  ---> Multiplicar 10 a la potnencia de cuantos flotantes hayan
#
#
# # IF ELSE
#
# ## compare Objects based on identity
# * Identical: ***is***, and ***is not***
#
# ## compare Objects based on value
# * >, < , ==
# * None, False, cero empty sequence
#
# ## True value
